# %% [markdown]
# <a href="https://colab.research.google.com/github/Pritijondhale97/Deep_Learning/blob/main/Regresion_with_Keras.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Regression with Keras

# %% [markdown]
# Switch from CPU to GPU. Always work on GPU runtime

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Data Ingestion

# %%
path = "https://raw.githubusercontent.com/Sindhura-tr/Datasets/refs/heads/main/PowerPlant.csv"
import pandas as pd
df = pd.read_csv(path)
df.head()
# Out:
#       AT      V       AP     RH      PE
# 0   8.34  40.77  1010.84  90.01  480.48
# 1  23.64  58.49  1011.40  74.20  445.75
# 2  29.74  56.90  1007.15  41.91  438.76
# 3  19.07  49.69  1007.22  76.79  453.09
# 4  11.80  40.66  1017.13  97.20  464.43

# %% [markdown]
# Perform the basic data quality checks

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9527 entries, 0 to 9567
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AT      9527 non-null   float64
#  1   V       9527 non-null   float64
#  2   AP      9527 non-null   float64
#  3   RH      9527 non-null   float64
#  4   PE      9527 non-null   float64
# dtypes: float64(5)
# memory usage: 446.6 KB

# %%
df.shape
# Out:
# (9527, 5)

# %%
df.columns
# Out:
# Index(['AT', 'V', 'AP', 'RH', 'PE'], dtype='object')

# %% [markdown]
# check for missing data/duplicated rows

# %%
df.isna().sum()
# Out:
# AT    0
# V     0
# AP    0
# RH    0
# PE    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df=df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # separate x & y features

# %%
x=df.drop(columns=["PE"])
y=df[["PE"]]

# %%
x.head()
# Out:
#       AT      V       AP     RH
# 0   8.34  40.77  1010.84  90.01
# 1  23.64  58.49  1011.40  74.20
# 2  29.74  56.90  1007.15  41.91
# 3  19.07  49.69  1007.22  76.79
# 4  11.80  40.66  1017.13  97.20

# %%
y.head()
# Out:
#        PE
# 0  480.48
# 1  445.75
# 2  438.76
# 3  453.09
# 4  464.43

# %% [markdown]
# Data Preprocessing and Data cleaning

# %%
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer

# %%
num_pipe = make_pipeline(SimpleImputer(strategy="mean"),StandardScaler()).set_output(transform="pandas")

# %%
X_pre = num_pipe.fit_transform(x)
X_pre.head()
# Out:
#          AT         V        AP        RH
# 0 -1.520448 -1.066041 -0.403535  1.141599
# 1  0.534897  0.330813 -0.309262  0.059223
# 2  1.354348  0.205475 -1.024725 -2.151400
# 3 -0.079020 -0.362884 -1.012941  0.236538
# 4 -1.055645 -1.074713  0.655349  1.633837

# %% [markdown]
# Perform train test split

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest = train_test_split(X_pre,y,train_size=0.75,random_state=42)

# %%
xtrain.head()
# Out:
#             AT         V        AP        RH
# 1845 -0.886381 -0.795657  0.961736  0.845161
# 8505  0.939249  0.960659 -1.268824 -0.564462
# 8152 -0.957579 -0.966717  0.729421  0.563784
# 5023  0.143978  0.439598  0.983620  0.489161
# 1744 -1.214161 -0.967505 -2.257003  1.596868

# %%
xtest.head()
# Out:
#             AT         V        AP        RH
# 1087  1.827212  1.120683 -0.125767 -1.414069
# 6319 -1.501641 -1.244984  0.044260 -0.467246
# 8052 -1.465370 -1.418408  0.399466 -1.082031
# 9524  0.150695  0.648495  0.731104 -0.002393
# 4463 -0.036032  1.128565 -0.361449  1.586599

# %%
ytrain.head()
# Out:
#           PE
# 1845  469.02
# 8505  436.65
# 8152  469.18
# 5023  445.18
# 1744  472.41

# %%
ytest.head()
# Out:
#           PE
# 1087  429.38
# 6319  485.29
# 8052  480.40
# 9524  452.30
# 4463  446.47

# %% [markdown]
# Modeel building with keras

# %%
from keras.models import Sequential
from keras.layers import Input, Dense

# %% [markdown]
# ![regression with keras.png](data:image/png;base64,...)

# %%
xtrain.shape
# Out:
# (7145, 4)

# %%
xtrain.shape[1]
# Out:
# 4

# %%
# Intialize the model
model = Sequential()

# Add the Input layer by providing features as Input
model.add(Input(shape=(xtrain.shape[1],)))

# Add the Dense layer - hidden layer 1
model.add(Dense(units=8,activation="relu"))

# Add another hidden layer 2
model.add(Dense(units=4,activation="relu"))

# Add the output layer
model.add(Dense(units=1,activation="linear"))

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 8)              │            40 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 4)              │            36 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │             5 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 81 (324.00 B)
#  Trainable params: 81 (324.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer="adam",loss="mse",metrics=["mae"])

# %% [markdown]
# Deep Learning
# train test split
# train model, further splitting will happens
# train data is further divided into training and validation
#
# Model will be compared with trianing scores and validated scores

# %% [markdown]
# Epoch: one complete pass of forward propagation and backpropagation

# %%
hist = model.fit(xtrain,ytrain,validation_split=0.2,epochs=100)
# Out:
# Epoch 1/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 206183.5938 - mae: 453.7442 - val_loss: 203723.9062 - val_mae: 451.0119
# Epoch 2/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 202874.2188 - mae: 450.0772 - val_loss: 195428.4375 - val_mae: 441.6823
# Epoch 3/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 192634.0781 - mae: 438.4702 - val_loss: 175558.2969 - val_mae: 418.3414
# Epoch 4/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 169725.3125 - mae: 411.1111 - val_loss: 142683.8594 - val_mae: 375.9820
# Epoch 5/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 134957.4531 - mae: 365.0157 - val_loss: 102586.5547 - val_mae: 315.1003
# Epoch 6/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 94824.1328 - mae: 301.2987 - val_loss: 65421.4648 - val_mae: 242.0039
# Epoch 7/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 60765.1016 - mae: 230.5938 - val_loss: 40046.0508 - val_mae: 177.0363
# Epoch 8/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 37474.0781 - mae: 170.2207 - val_loss: 27302.5645 - val_mae: 142.0267
# Epoch 9/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 26749.9824 - mae: 140.4692 - val_loss: 21832.8320 - val_mae: 126.4371
# Epoch 10/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 21504.6465 - mae: 125.7640 - val_loss: 18708.9902 - val_mae: 117.1859
# Epoch 11/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 17493.4727 - mae: 113.2677 - val_loss: 16215.8408 - val_mae: 109.3861
# Epoch 12/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 15441.1328 - mae: 106.7521 - val_loss: 13900.2412 - val_mae: 101.2844
# Epoch 13/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 12863.7354 - mae: 97.4728 - val_loss: 11747.3242 - val_mae: 92.9215
# Epoch 14/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 11219.3076 - mae: 90.9296 - val_loss: 9774.6025 - val_mae: 84.4123
# Epoch 15/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 
100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 20.7314 - mae: 3.6651 - val_loss: 21.6419 - val_mae: 3.6269
# Epoch 74/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 20.8217 - mae: 3.6563 - val_loss: 20.9658 - val_mae: 3.5555
# Epoch 75/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 21.8396 - mae: 3.7105 - val_loss: 20.9358 - val_mae: 3.5609
# Epoch 76/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 20.5391 - mae: 3.6112 - val_loss: 20.8410 - val_mae: 3.5382
# Epoch 77/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 21.0860 - mae: 3.6502 - val_loss: 20.9096 - val_mae: 3.5549
# Epoch 78/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 20.7518 - mae: 3.5941 - val_loss: 21.4213 - val_mae: 3.6208
# Epoch 79/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 21.2850 - mae: 3.6554 - val_loss: 21.0823 - val_mae: 3.5631
# Epoch 80/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 20.8208 - mae: 3.5987 - val_loss: 20.9783 - val_mae: 3.5585
# Epoch 81/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 19.9252 - mae: 3.5991 - val_loss: 21.0050 - val_mae: 3.5765
# Epoch 82/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 19.5917 - mae: 3.5739 - val_loss: 21.1503 - val_mae: 3.5535
# Epoch 83/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 19.9529 - mae: 3.5568 - val_loss: 21.1144 - val_mae: 3.5556
# Epoch 84/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 20.7837 - mae: 3.6595 - val_loss: 21.1153 - val_mae: 3.5748
# Epoch 85/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 19.7987 - mae: 3.5685 - val_loss: 21.1431 - val_mae: 3.5757
# Epoch 86/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 22.1035 - mae: 3.6914 - val_loss: 21.1936 - val_mae: 3.5633
# Epoch 87/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 22.0098 - mae: 3.6282 - val_loss: 21.1037 - val_mae: 3.5570
# Epoch 88/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 19.5548 - mae: 3.5481 - val_loss: 20.9260 - val_mae: 3.5579
# Epoch 89/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 20.6012 - mae: 3.6040 - val_loss: 21.3007 - val_mae: 3.6010
# Epoch 90/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 21.6224 - mae: 3.6831 - val_loss: 21.1053 - val_mae: 3.5891
# Epoch 91/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 20.4945 - mae: 3.5856 - val_loss: 21.3347 - val_mae: 3.6046
# Epoch 92/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 19.8927 - mae: 3.5973 - val_loss: 20.9005 - val_mae: 3.5585
# Epoch 93/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 21.4264 - mae: 3.6127 - val_loss: 21.3373 - val_mae: 3.6080
# Epoch 94/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 20.3834 - mae: 3.5668 - val_loss: 21.0420 - val_mae: 3.5846
# Epoch 95/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 21.3323 - mae: 3.6272 - val_loss: 20.9598 - val_mae: 3.5626
# Epoch 96/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 22.6611 - mae: 3.6114 - val_loss: 21.7182 - val_mae: 3.6566
# Epoch 97/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 20.6750 - mae: 3.5973 - val_loss: 20.9618 - val_mae: 3.5489
# Epoch 98/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 19.8668 - mae: 3.5662 - val_loss: 21.4057 - val_mae: 3.6100
# Epoch 99/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 19.7135 - mae: 3.5680 - val_loss: 21.7629 - val_mae: 3.6277
# Epoch 100/100
# 179/179 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 20.5462 - mae: 3.6258 - val_loss: 20.8826 - val_mae: 3.5571

# %% [markdown]
# # Evaluate the model

# %%
model.evaluate(xtrain,ytrain)
# Out:
# 224/224 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 19.9691 - mae: 3.5763
# [20.302570343017578, 3.5711047649383545]

# %%
model.evaluate(xtest,ytest)
# Out:
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 19.0257 - mae: 3.4961
# [20.13291358947754, 3.5669288635253906]

# %% [markdown]
# Learning curve

# %%
import matplotlib.pyplot as plt

plt.plot(hist.history["loss"],label="Training Loss")
plt.plot(hist.history["val_loss"],label="Validation Loss")
plt.xlabel("Number of Epochs")
plt.ylabel("Loss-MSE")
plt.legend()
plt.show()

# %% [markdown]
# Evaluate the model using testing data

# %%
ypred_test = model.predict(xtest)
ypred_test
# Out:
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# array([[427.05707],
#        [481.0965 ],
#        [482.64395],
#        ...,
#        [453.83255],
#        [476.5259 ],
#        [455.1094 ]], dtype=float32)

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

# %%
def evaluate_model(model,xdata,ydata):
  ypred=model.predict(xdata)

  MSE = mean_squared_error(ydata,ypred)
  MAE = mean_absolute_error(ydata,ypred)
  R2 = r2_score(ydata,ypred)

  print(f"MSE: {MSE}")
  print(f"MAE:{MAE}")
  print(f"R2-score: {R2}")

# %%
evaluate_model(model,xtrain,ytrain)
# Out:
# 224/224 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# MSE: 20.302566528320312
# MAE:3.5711047649383545
# R2-score: 0.929405927658081

# %%
evaluate_model(model,xtest,ytest)
# Out:
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# MSE: 20.132911682128906
# MAE:3.5669286251068115
# R2-score: 0.9325002431869507

# %% [markdown]
# Save the model

# %%
model.save("PowerplantPredictions.keras")

# %% [markdown]
# Above model provides ~93% r2 score in test data. Let's consider this model for final predictions

# %% [markdown]
# Load the keras models

# %%
from keras.models import load_model

# %%
m = load_model("/content/PowerplantPredictions.keras")

# %%
m.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 8)              │            40 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 4)              │            36 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │             5 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 245 (984.00 B)
#  Trainable params: 81 (324.00 B)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 164 (660.00 B)

# %%
path2 = "https://raw.githubusercontent.com/Sindhura-tr/Datasets/refs/heads/main/PowerPlantTest.csv"
xnew = pd.read_csv(path2)
xnew
# Out:
#    AT     V      AP    RH
# 0  25  51.5  1000.1  57.0
# 1  32  41.0  1051.1  80.0
# 2  28   NaN  1010.2   NaN

# %%
xnew_pre = num_pipe.transform(xnew)
xnew_pre.head()
# Out:
#          AT         V        AP        RH
# 0  0.717594 -0.220203 -2.211551 -1.118316
# 1  1.657948 -1.047911  6.373998  0.456299
# 2  1.120603  0.000000 -0.511275  0.000000

# %%
PE_preds = m.predict(xnew_pre)
PE_preds = PE_preds.round(2)
PE_preds
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# array([[445.45],
#        [465.53],
#        [437.36]], dtype=float32)

# %% [markdown]
# Save the data to dataframe and then save the results to csv file

# %%
xnew["PE Predicted"] = PE_preds

# %%
xnew.columns
# Out:
# Index(['AT', 'V', 'AP', 'RH', 'PE Predicted'], dtype='object')

# %%
xnew["PE Predicted"] = xnew["PE Predicted"].round(2)
xnew
# Out:
#    AT     V      AP    RH  PE Predicted
# 0  25  51.5  1000.1  57.0    445.450012
# 1  32  41.0  1051.1  80.0    465.529999
# 2  28   NaN  1010.2   NaN    437.359985
